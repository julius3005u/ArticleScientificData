# %% [markdown]
# # Respuestas a Editor y Revisores — Evidencia mapeada (V14)
#
# Fecha: 2026-02-09
#
# Este notebook documenta, de forma **item-por-item**, cómo quedaron atendidos los comentarios del editor y revisores en la versión **V14** del manuscrito.
#
# **Fuentes de evidencia (autoridad):**
# - Manuscrito v14 (clean): `V14ScientificData/main_english_v14_final.tex`
# - Manuscrito v14 (tracked): `V14ScientificData/main_english_v14.tex`
# - Bibliografía v14: `V14ScientificData/referencias.bib`
#
# **Restricción importante:** este documento está anclado al manuscrito; no inspecciona archivos raw del dataset para justificar respuestas.

# %% [markdown]
# ## Cómo leer la evidencia
#
# Para cada ítem se reporta:
# - **Ubicación en el manuscrito (V14):** sección/subsección + figura/tabla/label si aplica.
# - **Evidencia (verbatim):** extractos TeX cortos tomados de v14.
# - **Respuesta:** qué se cambió/añadió y cómo satisface el requerimiento.
#
# Nota: las ubicaciones se expresan por **estructura** (no por número de línea) para que no sea frágil ante cambios menores.

# %% [markdown]
# ## Comentarios del Editor
#
# ### E1 — Proveer datos en formato estandarizado más allá de NumPy
# **Ubicación (V14):** Abstract; Data Records; Usage Notes.
#
# **Evidencia (verbatim):**
# ```tex
# Each signal is provided in three formats (NumPy arrays, plain text, and JSON) ...
# ```
# ```tex
# Regarding the three formats used ... (1) NumPy compressed format (.npz) ... (2) consolidated plain text (.txt) ... (3) JSON format (.json) ...
# ```
#
# **Respuesta:** V14 documenta explícitamente distribución multi-formato (.npz, .txt consolidado, .json) y añade un bloque descriptivo para semántica de cada formato; Usage Notes incluye ejemplo reproducible de lectura.
#
# ---
#
# ### E2 — Añadir citación formal del dataset (Zenodo) y citar donde corresponda
# **Ubicación (V14):** Data Records; Code availability.
#
# **Evidencia (verbatim):**
# ```tex
# The Complex Signal Benchmark Dataset (CoSiBD) is publicly available on Zenodo\cite{cosibd_zenodo_2025} ...
# ```
# ```tex
# Zenodo\cite{cosibd_zenodo_2025} (DOI: \href{https://doi.org/10.5281/zenodo.15138853}{10.5281/zenodo.15138853}).
# ```
#
# **Respuesta:** V14 incorpora una referencia bibliográfica formal a Zenodo (`cosibd_zenodo_2025`) y la cita en las secciones donde se describe la disponibilidad del dataset y su DOI.

# %% [markdown]
# ## Revisor #1
#
# ### R1-1 — Alcance: Data Descriptor (no resultados hypothesis-driven)
# **Ubicación (V14):** Technical Validation (framing de benchmarks/transfer).
#
# **Evidencia (verbatim):**
# ```tex
# ... provide a multi-scale super-resolution benchmark ... and illustrative transfer learning experiments ...
# ```
#
# **Respuesta:** V14 enmarca los experimentos como validación técnica/baselines ilustrativos para uso del dataset, alineado al formato Data Descriptor.
#
# ---
#
# ### R1-2 — Citar uso previo
# **Ubicación (V14):** Background & Summary.
#
# **Evidencia (verbatim):**
# ```tex
# CoSiBD has been previously used ... \cite{IbarraFiallo2024} ...
# ```
#
# **Respuesta:** Se declara el antecedente y se distingue de la contribución del Data Descriptor/dataset release.
#
# ---
#
# ### R1-3 — Justificar “realismo” (no ‘too artificial’)
# **Ubicación (V14):** Methods → Design rationale inspired by real signals; Figura `fig:design_rationale_motivations`.
#
# **Evidencia (verbatim):**
# ```tex
# ... real signals exhibit (i) non-stationary regime changes, (ii) coexisting low- and high-frequency components ...
# ... Figure~\ref{fig:design_rationale_motivations} provides qualitative examples ...
# ```
#
# **Respuesta:** V14 fija explícitamente qué propiedades de señales reales se buscan reflejar y conecta dichas propiedades con los mecanismos del generador.
#
# ---
#
# ### R1-4 — Documentación/justificación de ruido
# **Ubicación (V14):** Methods → Noise injection; Rationale for structured 50/60 Hz; Figura `fig:r1_4_powerline_noise`.
#
# **Evidencia (verbatim):**
# ```tex
# Two noise types are implemented: (1) Additive white Gaussian noise (AWGN) ... (2) structured sinusoidal noise bursts ...
# Noise is applied probabilistically with a fixed 50\% probability per signal.
# ```
#
# **Respuesta:** V14 especifica tipos de ruido, probabilidad y registro en metadata; además añade una motivación cualitativa para la interferencia tipo ‘mains hum’.
#
# ---
#
# ### R1-5 — Unidades, Hz y política de decimación (sin pre-filtro)
# **Ubicación (V14):** Methods → Resolution variation; Sampling units and frequency interpretation; Figura `fig:r1_5_sampling_units`.
#
# **Evidencia (verbatim):**
# ```tex
# Lower-resolution versions are created using simple decimation (uniform subsampling). ... without pre-filtering.
# Reconstructing low-pass filtered signals is not an objective of CoSiBD.
# ```
# ```tex
# ... interpreting it as physical time requires choosing a duration T ... the implied sampling rate is f_s = N/T ...
# ```
#
# **Respuesta:** V14 explicita (i) cómo interpretar Hz bajo una convención ilustrativa y (ii) la definición LR–HR como decimación uniforme sin pre-filtrado.
#
# ---
#
# ### R1-6 — Profundidad de Technical Validation
# **Ubicación (V14):** Technical Validation; Multi-Scale Super-Resolution Benchmark (`sec:multiscale-super-resolution-benchmark`); Transfer experiments (`sec:preliminary-application-results`).
#
# **Evidencia (verbatim):**
# ```tex
# This section evaluates ... dominant frequencies ... spectral stability ... effect of noise. Additionally, we provide a multi-scale ... and illustrative transfer ...
# ```
#
# **Respuesta:** V14 amplía validación: (a) análisis espectral, (b) baseline SR multi-factor con métricas, (c) transferencia ilustrativa con EEG y voz.
#
# ---
#
# ### R1-9 — Anotaciones por señal (segmentos/change-points)
# **Ubicación (V14):** Data Records → Metadata schema and example; Tabla `tab:metadata_schema`; Figura `fig:metadata_visualization`.
#
# **Evidencia (verbatim):**
# ```tex
# Per-signal metadata (frequency profiles with explicit change-points ... and segment labels (variation_type) ... and seeds) ...
# ```
#
# **Respuesta:** V14 documenta campos de metadata para change-points y etiquetas por segmento, y añade ejemplo concreto + visualización asociada.
#
# ---
#
# ### R1-10 — Flexibilidad de splits (no predefined split)
# **Ubicación (V14):** Usage Notes (párrafo inicial).
#
# **Evidencia (verbatim):**
# ```tex
# The dataset is distributed as a single, unified collection without a predefined train/validation/test split.
# Users should create partitions appropriate to their objectives ...
# ```
#
# **Respuesta:** Se aclara explícitamente que no se distribuyen particiones predefinidas; los splits usados en validación son de protocolo del experimento.
#
# ---
#
# ### R1-11 — Definir procedimiento PSD + dominante
# **Ubicación (V14):** Technical Validation → Analysis of Dominant Frequency Distribution.
#
# **Evidencia (verbatim):**
# ```tex
# ... computed the power spectral density (PSD) ...
# The PSD was estimated using Welch’s method ...
# ... dominant frequency was identified as the frequency at which the PSD reaches its maximum value.
# ```
#
# **Respuesta:** V14 deja explícito el método de estimación (Welch) y la definición operacional de frecuencia dominante.
#
# ---
#
# ### R1-16 — Code availability
# **Ubicación (V14):** Code availability (`sec:code-availability`).
#
# **Evidencia (verbatim):**
# ```tex
# The complete signal generation pipeline ... is available at: \href{...}{CoSiBD scripts on GitHub}.
# ... These scripts are distributed under the MIT License.
# ```
#
# **Respuesta:** V14 apunta al repositorio con el pipeline, describe qué incluye y explicita licencia.

# %% [markdown]
# ### Addendum — Escalamiento temporal y lectura en Hz
#
# **Ubicación (V14):** Methods → Sampling units and frequency interpretation; Figura `fig:r1_5_sampling_units`.
#
# **Evidencia (verbatim):**
# ```tex
# ... interpreting it as physical time requires choosing a duration T ...
# ... any band-specific interpretation in Hz ... should be understood under the chosen T; changing T rescales all reported Hz values ...
# ```
#
# **Respuesta:** V14 formaliza la convención de unidades para evitar ambigüedades y alinear la interpretación física con el uso del dataset como secuencias discretas para SR.

# %% [markdown]
# ### Addendum — Metadata schema + ejemplo concreto
#
# **Ubicación (V14):** Data Records → Metadata schema and example; Tabla `tab:metadata_schema`.
#
# **Evidencia (verbatim):**
# ```tex
# Table~\ref{tab:metadata_schema} summarizes representative fields contained in signals_metadata.json.
# A minimal example entry is shown below ...
# ```
#
# **Respuesta:** Se añade estructura (Field/Type/Example/Meaning), explicación de `variation_type` y un snippet JSON de ejemplo anclado a una semilla concreta.

# %% [markdown]
# ## Revisor #2
#
# ### R2-1 — Motivación y comparación con benchmarks existentes
# **Ubicación (V14):** Background & Summary → Related synthetic time-series resources; Tabla `tab:related_synthetic_datasets`; Methods → Design rationale (Figura `fig:design_rationale_motivations`).
#
# **Evidencia (verbatim):**
# ```tex
# Table~\ref{tab:related_synthetic_datasets} summarizes ...
# ... CoSiBD is designed to close the gap by providing a fixed, standardized set of LR--HR pairs ...
# ```
#
# **Respuesta:** V14 posiciona CoSiBD frente a recursos representativos y explicita el ‘gap’ (paired LR–HR SR + metadata + estandarización).
#
# ---
#
# ### R2-2 — Proveer baselines cuantitativos/visuales
# **Ubicación (V14):** Technical Validation → Multi-Scale Super-Resolution Benchmark; Tabla `tab:multiscale_benchmark`; Figuras `fig:multifactor_loss_curves`, `fig:multifactor_predictions`, `fig:spectral_analysis`, `fig:spectral_metrics`.
#
# **Evidencia (verbatim):**
# ```tex
# ... scaling factors: 5× (1000→5000), 10× (500→5000), 20× (250→5000), and 33× (150→5000).
# ```
#
# **Respuesta:** V14 añade un benchmark multi-factor con métricas de error y métricas espectrales (LSD/SCORR) + figuras cualitativas.
#
# ---
#
# ### R2-3 — Simplificar Figura 1 (generation process)
# **Ubicación (V14):** Methods; Figura `fig:generation_process`.
#
# **Evidencia (verbatim):**
# ```tex
# \includegraphics[width=0.35\textwidth]{diagrams/generation_process4.png}
# \caption{Schematic overview of the CoSiBD signal generation process.}
# ```
#
# **Respuesta:** La figura se presenta como esquema compacto y la explicación se lleva al texto (lista de pasos).
#
# ---
#
# ### R2-6 — Seeds y reproducibilidad
# **Ubicación (V14):** Abstract; Data Records; Tabla `tab:Parameter`.
#
# **Evidencia (verbatim):**
# ```tex
# ... including seeds for full reproducibility.
# ```
# ```tex
# Reproducibility is ensured through documented seeds ... unique seed (ranging from 10,000 to 12,499) ...
# ```
#
# **Respuesta:** V14 documenta semillas como parámetros registrados (no aleatorios) para regeneración determinista.

# %% [markdown]
# ### Addendum — Ejemplo mínimo de entrenamiento (synthetic-only)
#
# **Ubicación (V14):** Usage Notes → Training a baseline model (synthetic-only).
#
# **Evidencia (verbatim):**
# ```tex
# The following example illustrates a minimal synthetic-only training loop ...
# ```
#
# **Respuesta:** V14 incluye un loop end-to-end (carga, split, modelo 1D, optimizador, MSE, evaluación), suficiente como punto de partida reproducible dentro de un Data Descriptor.

# %% [markdown]
# ## Revisor #3
#
# ### R3-1 — Impacto: entrenar en simulado, validar en real
# **Ubicación (V14):** Technical Validation → Illustrative Transfer Learning Experiments (`sec:preliminary-application-results`).
#
# **Evidencia (verbatim):**
# ```tex
# ... evaluated on two distinct real-world domains: EEG clinical signals ... and VCTK speech recordings ...
# ```
#
# **Respuesta:** V14 presenta un protocolo ilustrativo de transferencia con dos dominios reales y estrategias de entrenamiento (Real/Synth/Mixed/Tuned).
#
# ---
#
# ### R3-2 — Conectar objetivos vs señales reales
# **Ubicación (V14):** Methods → Design rationale; Figura `fig:design_rationale_motivations`; Technical Validation (PSD/dominant frequency).
#
# **Respuesta:** V14 incluye motivación cualitativa (waveform + espectrograma) y validación cuantitativa para documentar que las variaciones controladas producen comportamientos relevantes (no estacionariedad, transientes, etc.).

# %% [markdown]
# ## Ejemplo de evidencia en tracked-changes (V14)
#
# **Ubicación (V14):** `main_english_v14.tex` (versión marcada).
#
# **Qué se busca mostrar:** que los cambios claves (p.ej., definición LR–HR por decimación, explicación de unidades/Hz, etc.) también existen en la versión con cambios marcados para auditoría editorial.
#
# **Nota:** el detalle de cambios marcados depende del lugar exacto donde se introdujo el texto y del uso de macros de tracked-changes; cuando no es robusto citar un macro específico, el anclaje principal es el contenido final y sus labels/figuras/tablas.
