# %% [markdown]
# ## Convención de referencia
#
# Para cada requerimiento:
# - **Dónde (Sección/Subsección):** nombre exacto del bloque del manuscrito.
# - **Qué artefacto:** Tabla/Figura/Lista/Texto (si aplica).
# - **Label(s):** `\label{...}` cuando exista.
# - **Observación breve:** por qué esa ubicación satisface el requerimiento.

# %% [markdown]
# # Editor requirements

# %% [markdown]
# ## [E1] Share data in standardized formats beyond NumPy arrays (CSV/JSON)
#
# **Dónde (Sección/Subsección):**
# - Abstract (menciona formatos y metadatos).
# - `\section*{Data Records}` (descripción explícita de formatos y archivos).
#
# **Qué artefacto:** texto descriptivo (lista de formatos y estructura de archivos).
#
# **Label(s):** N/A (requisito satisfecho por texto, no por figura/tabla).
#
# **Observación:** el manuscrito declara tres formatos (.npz, .txt consolidado, .json) y explica por qué se usa texto plano para series temporales; además especifica nombres de archivos y metadatos (`signals_metadata.json`, `dataset_summary.json`, `filtering_info.json`).

# %% [markdown]
# ## [E2] Add data citations for datasets in repositories with reference numbers
#
# **Dónde (Sección/Subsección):**
# - `\section*{Data Records}`: cita a Zenodo `\cite{cosibd_zenodo_2025}` y DOI.
# - `\section*{Code availability}`: reiteración de DOI/cita.
#
# **Qué artefacto:** cita bibliográfica + DOI.
#
# **Label(s):** N/A.
#
# **Observación:** el dataset queda citado formalmente dentro del texto (no sólo como URL).

# %% [markdown]
# # Reviewer #1 requirements

# %% [markdown]
# ## [R1-1] Paper lacks scientific results or hypothesis-driven interpretations beyond basic data quality
#
# **Dónde (Sección/Subsección):** `\section*{Technical Validation}`
# - `\subsection*{Anti-Aliasing Filter Validation}`
# - `\subsection*{Multi-Scale Super-Resolution Benchmark}`
# - `\subsection*{Preliminary Application Results}`
#
# **Qué artefacto:** tabla + figuras + texto cuantitativo.
#
# **Label(s):**
# - Table multi-scale benchmark: `\label{tab:multiscale_benchmark}`
# - Loss curves: `\label{fig:multifactor_loss_curves}`
# - Predictions: `\label{fig:multifactor_predictions}`
# - Spectrogram grid: `\label{fig:spectral_analysis}`
# - Spectral metrics trends: `\label{fig:spectral_metrics}`
# - CNN transfer MAE table: `\label{tab:cnn_results}`
# - EEG/VCTK comparisons: `\label{fig:model_comparisons}` (subfigs `fig:eeg_comparison`, `fig:vctk_comparison`)
#
# **Observación:** el manuscrito aporta validación cuantitativa multi-escala (MSE + métricas espectrales) y transferencia a señales reales (MAE y mejoras porcentuales), más validación de anti-aliasing.

# %% [markdown]
# ## [R1-2] Missing explicit reference for conference presentation mentioned in manuscript
#
# **Dónde (Sección/Subsección):** `\section*{Background \& Summary}`
#
# **Qué artefacto:** cita bibliográfica del trabajo COINS.
#
# **Label(s):** N/A.
#
# **Observación:** el manuscrito incluye la referencia `\cite{IbarraFiallo2024}` en el texto introductorio.

# %% [markdown]
# ## [R1-3] No evidence that synthetic signals resemble real-world time series
#
# **Dónde (Sección/Subsección):** `\section*{Technical Validation}` → `\subsection*{Preliminary Application Results}`
#
# **Qué artefacto:** tabla de MAE + figuras de comparación (EEG/VCTK) + texto cuantitativo.
#
# **Label(s):** `\label{tab:cnn_results}`, `\label{fig:model_comparisons}`
#
# **Observación:** se reportan mejoras cuantitativas en datos reales usando estrategias de entrenamiento con datos sintéticos (no se afirma reemplazo de datos reales).

# %% [markdown]
# ## [R1-4] Noise model undocumented; single-tone sinusoid not justified
#
# **Dónde (Sección/Subsección):**
# - `\section*{Methods}` (`\label{sec:methods}`): paso 7 (Noise injection) describe dos tipos de ruido y probabilidad.
# - `\section*{Technical Validation}` (`\label{sec:technical-validation}`): `\subsection*{Impact of Noise on Frequency Characteristics}` y figura PSD con ruido.
#
# **Qué artefacto:** texto metodológico + figuras ilustrativas.
#
# **Label(s):** `\label{fig:noise_psd}`; ejemplos de ruido: `\label{fig:noise_ruido}` (subfigs `fig:noise1`..`fig:noise4`).
#
# **Observación:** se especifica ruido Gaussiano y ruido estructurado (sinusoidal) con probabilidad 50%, y se muestra el impacto en PSD.

# %% [markdown]
# ## [R1-5] Sampling frequency undefined; no anti-aliasing before subsampling; time units missing; aliasing artifacts
#
# **Dónde (Sección/Subsección):**
# - Abstract: especifica dominio y muestras (fs implícita y resoluciones).
# - `\section*{Methods}` (`\label{sec:methods}`): paso 6 (Resolution variation) documenta re-evaluación y downsampling con anti-aliasing (Butterworth, orden 8, cutoff 0.9 Nyquist).
# - `\section*{Data Records}` (`\label{sec:data-records}`): lista resoluciones y fs aproximadas; describe versiones simples vs filtradas.
# - `\section*{Technical Validation}` (`\label{sec:technical-validation}`): `\subsection*{Anti-Aliasing Filter Validation}` (`\label{sec:anti-aliasing-filter-validation}`) (validación, fórmula de cutoff y nota de variantes).
#
# **Qué artefacto:** texto técnico + lista de resoluciones/fs.
#
# **Label(s):** N/A (principalmente texto), más tabla/figuras asociadas a validación global.
#
# **Observación:** el manuscrito fija fs para HR y fs_target por resolución; define anti-aliasing y ofrece ambas variantes (filtrada/no filtrada).

# %% [markdown]
# ## [R1-6] Technical validation superficial, qualitative, conceptually flawed
#
# **Dónde (Sección/Subsección):** `\section*{Technical Validation}` completo, en particular:
# - `\subsection*{Anti-Aliasing Filter Validation}` (`\label{sec:anti-aliasing-filter-validation}`)
# - `\subsection*{Multi-Scale Super-Resolution Benchmark}` (`\label{sec:multiscale-super-resolution-benchmark}`)
# - `\subsection*{Preliminary Application Results}` (`\label{sec:preliminary-application-results}`)
#
# **Qué artefacto:** tabla + figuras + metodología + métricas cuantitativas.
#
# **Label(s):** `tab:multiscale_benchmark`, `fig:multifactor_loss_curves`, `fig:spectral_metrics`, `tab:cnn_results`.
#
# **Observación:** se reemplaza una validación meramente cualitativa por benchmark, métricas espectrales y transferencia a real.

# %% [markdown]
# ## [R1-7] Claims about frequency content stability lack anti-aliasing filters
#
# **Dónde (Sección/Subsección):**
# - `\section*{Methods}` (`\label{sec:methods}`): paso 6 (anti-aliasing previo al resampling).
# - `\section*{Technical Validation}` (`\label{sec:technical-validation}`): `\subsection*{Anti-Aliasing Filter Validation}` (`\label{sec:anti-aliasing-filter-validation}`).
#
# **Qué artefacto:** texto técnico con fórmula de cutoff y justificación; nota de que se proveen versiones filtradas y no filtradas.
#
# **Label(s):** N/A.
#
# **Observación:** la estabilidad espectral se discute con y sin anti-aliasing, y se formaliza el diseño del filtro.

# %% [markdown]
# ## [R1-8] Mischaracterization of noise as Gaussian/broadband when it's deterministic sinusoid
#
# **Dónde (Sección/Subsección):** `\section*{Methods}`: paso 7 (Noise injection).
#
# **Qué artefacto:** texto metodológico (dos tipos de ruido).
#
# **Label(s):** N/A.
#
# **Observación:** se explicita ruido Gaussiano y ruido sinusoidal estructurado; se elimina la afirmación de ruido exclusivamente Gaussiano/banda ancha.

# %% [markdown]
# ## [R1-9] Missing annotations for signal segments with changing frequency content
#
# **Dónde (Sección/Subsección):** `\section*{Data Records}` (metadatos por señal y JSON consolidado).
#
# **Qué artefacto:** texto que describe estructura de metadatos (`signals_metadata.json`) y campos (per-interval, parámetros de spline, ruido, filtros, seeds).
#
# **Label(s):** N/A.
#
# **Observación:** el manuscrito declara metadatos por señal con parámetros por intervalos/segmentos y seeds, satisfaciendo la necesidad de anotación.

# %% [markdown]
# ## [R1-10] Predefined validation sets with undocumented selection criteria
#
# **Dónde (Sección/Subsección):**
# - `\\section*{Usage Notes}` (`\\label{sec:usage-notes}`): regla de emparejamiento por índice de fila y declaración explícita de que el dataset se distribuye sin split fijo.
# - `\\section*{Technical Validation}` → `\\subsection*{Multi-Scale Super-Resolution Benchmark}` (`\\label{sec:multiscale-super-resolution-benchmark}`): se indica que el split 2,000 train / 500 val es un protocolo experimental (partición específica del benchmark), no una partición distribuida con el dataset.
#
# **Qué artefacto:** texto (política de split) + descripción de protocolo experimental.
#
# **Label(s):** `tab:multiscale_benchmark` (para el bloque experimental).
#
# **Observación:** el dataset no se presenta como entregado con un split fijo; cualquier split es específico del experimento reportado. El benchmark explicita que la partición 2,000/500 es sólo para ese protocolo (no “validation set” predefinido del dataset).

# %% [markdown]
# ## [R1-11] Dataset poorly justified; vague assertions without quantitative support
#
# **Dónde (Sección/Subsección):** `\\section*{Technical Validation}`
#
# - `\\subsection*{Impact of Noise on Frequency Characteristics}` (`fig:noise_psd`).
# - `\\subsection*{Multi-Scale Super-Resolution Benchmark}` (`tab:multiscale_benchmark`, `fig:multifactor_loss_curves`, `fig:multifactor_predictions`, `fig:spectral_analysis`, `fig:spectral_metrics`).
# - `\\subsection*{Preliminary Application Results}` (`tab:cnn_results`, `fig:model_comparisons`).
#
# **Qué artefacto:** edición de texto para reemplazar afirmaciones vagas o demasiado fuertes (p.ej., “robust/confirm/demonstrate/absence of overfitting”, umbrales no citados) por descripciones ancladas explícitamente a tablas/figuras y métricas reportadas. Además, se corrige una inconsistencia textual del benchmark (evitar afirmar “sub-0.01 MSE” cuando la tabla reporta otra escala).
#
# **Label(s):** `fig:noise_psd`, `tab:multiscale_benchmark`, `fig:multifactor_loss_curves`, `fig:multifactor_predictions`, `fig:spectral_analysis`, `fig:spectral_metrics`, `tab:cnn_results`, `fig:model_comparisons`.
#
# **Observación:** el manuscrito justifica el dataset con resultados cuantitativos y referencias directas a los artefactos (tablas/figuras) en lugar de afirmaciones generales sin soporte.

# %% [markdown]
# ## [R1-12] No indication dataset captures diversity/complexity of real-world signals
#
# **Dónde (Sección/Subsección):**
# - `\\section*{Data Records}`: párrafo explícito (insertado tras `tab:Parameter`) que describe e interpreta la diversidad/complexidad en términos de ejes de variación y la ancla a artefactos cuantitativos.
# - `\\section*{Data Records}`: ejemplos visuales de variabilidad (`fig:amplitud`, `fig:simples`).
# - `\\section*{Technical Validation}`: evidencia cuantitativa de variación espectral y condiciones experimentales (`fig:dominant_frequency_distribution`, `tab:density_label`, `fig:average_psd`, `fig:noise_psd`).
# - `\\subsection*{Preliminary Application Results}`: evidencia de utilidad/transferencia a señales reales (`tab:cnn_results`, `fig:model_comparisons`).
#
# **Qué artefacto:** texto explícito (con referencias) + figuras/tablas existentes que caracterizan variabilidad y propiedades espectrales; y resultados de transferencia a EEG/VCTK reportados en la sección de aplicación preliminar.
#
# **Label(s):** `tab:Parameter`, `fig:amplitud`, `fig:simples`, `fig:dominant_frequency_distribution`, `tab:density_label`, `fig:average_psd`, `fig:noise_psd`, `tab:cnn_results`, `fig:model_comparisons`.
#
# **Observación:** el manuscrito deja claro que CoSiBD es sintético (no ajustado a una distribución específica de un dominio), pero documenta diversidad/complexidad mediante ejes de variación controlados y evidencia cuantitativa (distribuciones/PSD) más ejemplos representativos; además reporta un protocolo de transferencia a señales reales como evidencia de utilidad práctica.

# %% [markdown]
# ## [R1-13] Critical details missing: sampling frequency, time units, noise characteristics
#
# **Dónde (Sección/Subsección):**
# - Abstract (muestras/dominio).
# - `\section*{Data Records}` (fs aproximadas por resolución).
# - `\section*{Methods}`: pasos 6 y 7 (resolución y ruido).
#
# **Qué artefacto:** texto + figuras con ejes.
#
# **Label(s):** figuras varias (e.g., `fig:amplitud`, `fig:average_psd`, `fig:noise_psd`).
#
# **Observación:** se incorporan fs y descripción de ruido; las figuras reportadas incluyen unidades y contexto.

# %% [markdown]
# ## [R1-14] File descriptions basic; metadata insufficient for advanced uses
#
# **Dónde (Sección/Subsección):** `\section*{Data Records}` (estructura de metadatos y archivos de configuración).
#
# **Qué artefacto:** descripción detallada de metadatos + tabla de parámetros.
#
# **Label(s):** `\label{tab:Parameter}`.
#
# **Observación:** se documentan parámetros de generación (tensión, offsets, probabilidades, seeds) y se especifican archivos JSON de metadatos.

# %% [markdown]
# ## [R1-15] Terms “samples / points / signals” undefined or inconsistent
#
# **Dónde (Sección/Subsección):** `\section*{Data Records}` (lista de resoluciones: “samples (or points)”).
#
# **Qué artefacto:** texto terminológico.
#
# **Label(s):** N/A.
#
# **Observación:** se aclara equivalencia y uso consistente de “samples/points” en el contexto del dataset.

# %% [markdown]
# ## [R1-16] Code shared, but documentation/cleanup could improve
#
# **Dónde (Sección/Subsección):** `\section*{Code availability}`.
#
# **Qué artefacto:** descripción ampliada del repositorio (módulos, reproducibilidad, notebooks).
#
# **Label(s):** N/A.
#
# **Observación:** el manuscrito describe explícitamente el pipeline modular y su relación con regeneración/uso, mejorando documentación.

# %% [markdown]
# # Reviewer #2 requirements

# %% [markdown]
# ## [R2-1] Signals limited; motivate relevance; compare with benchmarks
#
# **Dónde (Sección/Subsección):**
# - `\section*{Background \& Summary}` (motivación y alcance).
# - `\section*{Technical Validation}` (benchmark y transferencia).
#
# **Qué artefacto:** texto motivacional + benchmark + transferencia a real.
#
# **Label(s):** `tab:multiscale_benchmark`, `tab:cnn_results`.
#
# **Observación:** el manuscrito posiciona CoSiBD como benchmark controlado y aporta comparaciones cuantitativas.

# %% [markdown]
# ## [R2-2] No numerical results/baselines
#
# **Dónde (Sección/Subsección):** `\section*{Technical Validation}` → Multi-Scale Benchmark + Preliminary Application Results.
#
# **Qué artefacto:** tabla benchmark + métricas espectrales + tabla MAE real.
#
# **Label(s):** `tab:multiscale_benchmark`, `fig:spectral_metrics`, `tab:cnn_results`.
#
# **Observación:** se incorporan baselines cuantitativos y métricas reproducibles.

# %% [markdown]
# ## [R2-3] Figure 1 too much text
#
# **Dónde (Sección/Subsección):** `\section*{Methods}`: Figura del proceso.
#
# **Qué artefacto:** figura esquemática simplificada.
#
# **Label(s):** `\label{fig:generation_process}`.
#
# **Observación:** la figura se presenta como esquema; el detalle se mueve a texto/caption.

# %% [markdown]
# ## [R2-4] Figures lack axis labels/units
#
# **Dónde (Sección/Subsección):** Figuras en `Data Records` y `Technical Validation` (captions y ejes).
#
# **Qué artefacto:** figuras actualizadas (ejemplos, PSD, métricas).
#
# **Label(s):** ejemplos: `fig:amplitud`, `fig:average_psd`, `fig:noise_psd`, `fig:spectral_metrics`.
#
# **Observación:** se asegura etiquetado consistente (tiempo, frecuencia, amplitud) en figuras regeneradas.

# %% [markdown]
# ## [R2-5] Code examples too basic
#
# **Dónde (Sección/Subsección):** `\section*{Usage Notes}` y `\section*{Code availability}`.
#
# **Qué artefacto:** ejemplos de lectura/visualización + descripción de pipeline modular.
#
# **Label(s):** N/A.
#
# **Observación:** se incluye flujo de lectura de datos por índice, formatos y metadatos, más descripción de módulos.

# %% [markdown]
# ## [R2-6] RNG lacks fixed seeds
#
# **Dónde (Sección/Subsección):** `\section*{Methods}` y `\section*{Data Records}` (seeds documentadas en metadatos).
#
# **Qué artefacto:** texto + tabla de parámetros.
#
# **Label(s):** `tab:Parameter`.
#
# **Observación:** se declara seed por señal (rango) y la existencia de metadatos para reproducción exacta.

# %% [markdown]
# ## [R2-7] Typos / repetition
#
# **Dónde (Sección/Subsección):** cambios distribuidos en todo el manuscrito.
#
# **Qué artefacto:** edición textual (sin un único bloque).
#
# **Label(s):** N/A.
#
# **Observación:** este requerimiento se satisface por correcciones de estilo; se mantiene control en `main_englishv09.tex` vía track changes.

# %% [markdown]
# ## [R2-8] Insufficient novelty/depth
#
# **Dónde (Sección/Subsección):**
# - `\section*{Background \& Summary}` (posicionamiento de contribución).
# - `\section*{Data Records}` (detalle de dataset/metadatos).
# - `\section*{Technical Validation}` (validación cuantitativa).
#
# **Qué artefacto:** texto + resultados cuantitativos.
#
# **Label(s):** `tab:multiscale_benchmark`, `fig:spectral_metrics`, `tab:cnn_results`.
#
# **Observación:** la “profundidad” se sostiene por validación cuantitativa y trazabilidad/reproducibilidad; el enfoque sigue siendo un dataset paper (no claims inflados).

# %% [markdown]
# # Reviewer #3 requirements

# %% [markdown]
# ## [R3-1] Demonstrative impact: train DL on synthetic, validate on real
#
# **Dónde (Sección/Subsección):** `\section*{Technical Validation}` → `\subsection*{Preliminary Application Results}`.
#
# **Qué artefacto:** MAE real (EEG/VCTK) + figuras de comparación.
#
# **Label(s):** `tab:cnn_results`, `fig:model_comparisons`.
#
# **Observación:** se muestra impacto mediante protocolo de entrenamiento y validación en dos dominios reales, con métricas cuantitativas.

# %% [markdown]
# ## [R3-2] Needs side-by-side comparison of variability, stability, realism vs real-world signals
#
# **Dónde (Sección/Subsección):**
# - `\section*{Data Records}`: ejemplos de señales sintéticas (variabilidad).
# - `\section*{Technical Validation}`: métricas espectrales (estabilidad) + transferencia a real (realismo/transferencia).
#
# **Qué artefacto:** figuras de ejemplos + figuras/métricas espectrales + tabla MAE real.
#
# **Label(s):** `fig:amplitud`, `fig:simples`, `fig:spectral_metrics`, `tab:cnn_results`.
#
# **Observación:** el manuscrito combina comparaciones internas (sintético multi-resolución) con evidencia de desempeño en real (transferencia).
